# %%
# !pip intsall pandas
# Out:
# ERROR: unknown command "intsall" - maybe you meant "install"

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas 
import numpy

# %%
lst=[1,2,3,5]

# %%
numpy.array(lst)
# Out:
# array([1, 2, 3, 5])

# %%
pandas.Series(lst)
# Out:
# 0    1
# 1    2
# 2    3
# 3    5
# dtype: int64

# %%
[lst,lst,lst]
# Out:
# [[1, 2, 3, 5], [1, 2, 3, 5], [1, 2, 3, 5]]

# %%
df=pandas.DataFrame([lst,lst,lst], columns=['A','B','C','D'])

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    A  B  C  D
# 0  1  2  3  5
# 1  1  2  3  5
# 2  1  2  3  5

# %%
del df

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
