# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("Data_Set/weight-height.csv")

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.shape
# Out:
# (10000, 3)

# %%
sns.distplot(df["Height"])
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_15332\1870637031.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Height"])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(df["Height"])
# Out:
# <Axes: ylabel='Height'>

# %%
df["Height"].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
max_limit = df["Height"].quantile(0.99)
min_limit = df["Height"].quantile(0.01)

# %%
max_limit
# Out:
# np.float64(74.7857900583366)

# %%
# Trimming
new_data = df[(df["Height"]>min_limit) & (df["Height"]<max_limit)]

# %%
sns.distplot(new_data["Height"])
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_15332\4021081980.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_data["Height"])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(new_data["Height"])
# Out:
# <Axes: ylabel='Height'>

# %%
#capping
new_data2 = df.copy()
new_data2["Height"] = np.where(df["Height"]>max_limit,max_limit, np.where(df["Height"]<min_limit,min_limit, df["Height"]))

# %%
sns.distplot(new_data2["Height"])
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_15332\1197117282.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_data2["Height"])
# <Axes: xlabel='Height', ylabel='Density'>
