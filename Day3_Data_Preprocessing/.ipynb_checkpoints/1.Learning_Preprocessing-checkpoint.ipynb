# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is A82D-86F7
#
#  Directory of D:\Data_Analysis\Day3_Data_Preprocessing
#
# 12-03-2026  22:41    <DIR>          .
# 12-03-2026  22:40    <DIR>          ..
# 12-03-2026  22:41    <DIR>          .ipynb_checkpoints
# 12-03-2026  22:41               337 Learning_Preprocessing.ipynb
#                1 File(s)            337 bytes
#                3 Dir(s)  361,887,571,968 bytes free

# %%
ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is A82D-86F7
#
#  Directory of D:\Data_Analysis\Day3_Data_Preprocessing
#
# 12-03-2026  22:43    <DIR>          .
# 12-03-2026  22:40    <DIR>          ..
# 12-03-2026  22:41    <DIR>          .ipynb_checkpoints
# 12-03-2026  22:43    <DIR>          Google_Playstore
# 12-03-2026  22:41               337 Learning_Preprocessing.ipynb
#                1 File(s)            337 bytes
#                4 Dir(s)  361,884,876,800 bytes free

# %%
data = pd.read_csv("Google_Playstore/googleplaystore.csv")

# %%
data
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10836       10836                                   Sya9a Maroc - FR
# 10837       10837                   Fr. Mike Schmitz Audio Teachings
# 10838       10838                             Parkinson Exercices FR
# 10839       10839                      The SCP Foundation DB fr nn5n
# 10840       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating Reviews                Size     Installs  \
# ...

# %%
data.isnull().sum()    #Everything is false beacuse no value NaN here
# Out:
# Unnamed: 0           0
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Price                0
# Content Rating       1
# Genres               0
# Released             0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df = data.dropna()

# %%
df
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10834       10834                                      FR Calculator
# 10836       10836                                   Sya9a Maroc - FR
# 10837       10837                   Fr. Mike Schmitz Audio Teachings
# 10839       10839                      The SCP Foundation DB fr nn5n
# 10840       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating Reviews                Size     Installs  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Price             0
# Content Rating    0
# Genres            0
# Released          0
# Current Ver       0
# Android Ver       0
# dtype: int64
