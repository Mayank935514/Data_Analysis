# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is A82D-86F7
#
#  Directory of D:\Data_Analysis\Day3_Data_Preprocessing
#
# 13-03-2026  17:05    <DIR>          .
# 12-03-2026  22:40    <DIR>          ..
# 13-03-2026  17:05    <DIR>          .ipynb_checkpoints
# 13-03-2026  17:01            27,835 1.Learning_Preprocessing.ipynb
# 13-03-2026  17:05               617 2.DataAnalysis_Numeric.ipynb
# 12-03-2026  22:43    <DIR>          Google_Playstore
#                2 File(s)         28,452 bytes
#                4 Dir(s)  361,884,803,072 bytes free

# %%
data = pd.read_csv("Google_Playstore/googleplaystore.csv").dropna()

# %%
data
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10834       10834                                      FR Calculator
# 10836       10836                                   Sya9a Maroc - FR
# 10837       10837                   Fr. Mike Schmitz Audio Teachings
# 10839       10839                      The SCP Foundation DB fr nn5n
# 10840       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating Reviews                Size     Installs  \
# ...

# %% [markdown]
# ## -------------------------
# ## Data Analysis--> Numeric
# ## -------------------------

# %% [markdown]
# ## Q1.Finding Average Rating

# %%
round(int(sum(data['Rating']))/9360)
# Out:
# 4

# %%
float(str(int(sum(data['Rating']))/9360)[:4] )       #returning first 4 characters
# Out:
# 4.19

# %% [markdown]
# ## Q2.How many Apps are there with ratin 5?

# %%
count = 0
for i in data['Rating']:
    if  i==5.0:
        count+=1
print("There are",count,"Applications with rating 5")
# Out:
# There are 274 Applications with rating 5

# %% [markdown]
# ## Data Analysis--> Categorical

# %%
print("There are",len(data['Category'].unique()),"Categories are there")
# Out:
# There are 33 Categories are there

# %%
for i in data['Category'].unique():
    print(i)
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION

# %% [markdown]
# ## Data Analysis--> Automatic Categorical

# %% [markdown]
# ## Q1.Total no. of apps in each category

# %%
categories = {}
for name in data['Category'].unique():
    count=0
    for i in data['Category']:
        if i==name:
            count+=1
    categories[name] = count

# %%
categories
# Out:
# {'ART_AND_DESIGN': 61,
#  'AUTO_AND_VEHICLES': 73,
#  'BEAUTY': 42,
#  'BOOKS_AND_REFERENCE': 178,
#  'BUSINESS': 303,
#  'COMICS': 58,
#  'COMMUNICATION': 328,
#  'DATING': 195,
#  'EDUCATION': 155,
#  'ENTERTAINMENT': 149,
#  'EVENTS': 45,
#  'FINANCE': 323,
#  'FOOD_AND_DRINK': 109,
#  'HEALTH_AND_FITNESS': 297,
#  'HOUSE_AND_HOME': 76,
#  'LIBRARIES_AND_DEMO': 64,
#  'LIFESTYLE': 314,
#  'GAME': 1097,
#  'FAMILY': 1746,
#  'MEDICAL': 350,
#  'SOCIAL': 259,
#  'SHOPPING': 238,
#  'PHOTOGRAPHY': 317,
#  'SPORTS': 319,
#  'TRAVEL_AND_LOCAL': 226,
#  'TOOLS': 733,
#  'PERSONALIZATION': 312,
#  'PRODUCTIVITY': 351,
#  'PARENTING': 50,
#  'WEATHER': 75,
#  'VIDEO_PLAYERS': 160,
#  'NEWS_AND_MAGAZINES': 233,
#  'MAPS_AND_NAVIGATION': 124}

# %%
categories['MAPS_AND_NAVIGATION']
# Out:
# 124

# %%
data['Category'].describe()
# Out:
# count       9360
# unique        33
# top       FAMILY
# freq        1746
# Name: Category, dtype: object
